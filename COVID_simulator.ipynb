# %% [markdown]
# # 0. Libraries import

# %% [markdown]
# Check that we are using the intel python distribution

# %%
# !ls
# Out:
# COVID_simulator.ipynb  SIReNet_new  SIReNet.py

# %%
# !pwd
# Out:
# /home/mrcharles/SIReNet_project

# %% [markdown]
# # 1. Numba class creation

# %%
#filter not really clear deprecation warning by numba (incomplete docs)
import warnings
from numba.core.errors import NumbaDeprecationWarning
warnings.filterwarnings('ignore',category=NumbaDeprecationWarning)

# %%
from SIReNet.sparse_graph import SparseGraph

# %%
a = Multinomial()

# %%
from SIReNet.numba_samp import Dirichlet
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-47a933986e63> in <module>
# ----> 1 from SIReNet.numba_samplers import Dirichlet
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'SIReNet.numba_samplers'; 'SIReNet' is not a package

# %%
prova = Node(pop_size=1000)
prova.sampler_initializer()

# %%
prova.create_families()

# %%
prova.adjacency
# Out:
# <1000x1000 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 1910 stored elements in Dictionary Of Keys format>

# %%
prova.compute_common_neighbors()
# Out:
# <1000x1000 sparse matrix of type '<class 'numpy.int16'>'
# 	with 2910 stored elements in Dictionary Of Keys format>

# %%
prova.add_links(get_richer_step=2)

# %%
prova.degree_distribution()
# Out:
# NetworkX graph not initialized. Run build_graph method

# %%
prova.compute_common_neighbors()
# Out:
# <1000x1000 sparse matrix of type '<class 'numpy.int16'>'
# 	with 68012 stored elements in Dictionary Of Keys format>

# %%
prova.start_infection(contagion_probability=0.05)
# Out:
# 38 people have been infected

# %%
prova.initialize_individual_factors()

# %%
prova.infect_over_time
# Out:
# array([None, 38, 55, 100, 165, 239, 325, 385, 367, 348, 348, 343, 333,
#        335], dtype=object)

# %%
prova.propagate_infection(mu=2)
prova.propagation_stats()
# Out:
# -- EPIDEMICS --
# Actual number of infect people: 335
# New Recovered: 6
# New Deaths: 1
# New Infects: 2
#
#
# -- MODEL DYNAMICS --
# - Scores
# Min score: 0.0
# Max score: 17.0
# Mean score: 1.766
# Variance: 6.928172172172171
# Skewness: 2.046920316335562
#
#
# 15th percentile: 0.0
# 25th percentile: 0.0
# 50th percentile: 0.0
# 75th percentile: 3.0
# 90th percentile: 5.0
# - Probs
# Min score: 0.0
# Max score: 0.999999999993811
# Mean score: 0.2916823559293108
# Variance: 0.17302972506156625
# Skewness: 0.8224842701512977
#
#
# 15th percentile: 0.0
# 25th percentile: 0.0
# 50th percentile: 0.0
# 75th percentile: 0.6766764161830634
# 90th percentile: 0.9834363915193856
